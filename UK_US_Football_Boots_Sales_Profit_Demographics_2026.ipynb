# %%
import pandas as pd

# Template rows for UK and US markets for selected models
data = [
    # Puma: UK
    {
        "brand": "PUMA",
        "model": "King 20 Match FG/AG",
        "market": "UK",
        "currency": "GBP",
        "price": 28.00,          # example current listing price
        "sales_volume_units": None,   # fill with real units sold
        "sales_volume_value": None,   # fill with GBP revenue
        "profit_margin_percent": None, # fill with real margin %
        "demographics_primary_age": None,   # e.g., "18-24"
        "demographics_secondary_age": None, # e.g., "25-34"
        "demographics_gender": None,       # e.g., "Male", "Female", "Mixed"
        "demographics_income_bracket": None, # optional
        "notes": "Classic control line; UK deep discount; track stock constraints."
    },
    # Puma: US
    {
        "brand": "PUMA",
        "model": "King 20 Ultimate",
        "market": "US",
        "currency": "USD",
        "price": 220.00,
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Premium US SKU; good review context for comfort and balance."
    },
    # Mizuno: UK
    {
        "brand": "Mizuno",
        "model": "Morelia Neo IV Beta MIJ FG",
        "market": "UK",
        "currency": "GBP",
        "price": 250.00,
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Premium leather boot; UK premium positioning."
    },
    # Mizuno: US
    {
        "brand": "Mizuno",
        "model": "Morelia Neo IV Beta AG",
        "market": "US",
        "currency": "USD",
        "price": 320.00,
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Premium US listing; track availability limits or regional restrictions."
    },
    # New Balance: UK
    {
        "brand": "New Balance",
        "model": "Tekela Elite FG V5",
        "market": "UK",
        "currency": "GBP",
        "price": 126.00,
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Discounted UK price; consider stock/seasonal restock."
    },
    # New Balance: US
    {
        "brand": "New Balance",
        "model": "Tekela Elite FG V5",
        "market": "US",
        "currency": "USD",
        "price": None, # add US price if available
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Add US price once confirmed; track review sentiment."
    },
    # Skechers: UK
    {
        "brand": "Skechers",
        "model": "SKX 1 Firm Ground",
        "market": "UK",
        "currency": "GBP",
        "price": 30.00,
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "New entrant; track strong discounting and availability."
    },
    # Skechers: US
    {
        "brand": "Skechers",
        "model": "SKX line",
        "market": "US",
        "currency": "USD",
        "price": None, # add US price if available
        "sales_volume_units": None,
        "sales_volume_value": None,
        "profit_margin_percent": None,
        "demographics_primary_age": None,
        "demographics_secondary_age": None,
        "demographics_gender": None,
        "demographics_income_bracket": None,
        "notes": "Add US SKU price; track comfort-focused demographics."
    }
]

df = pd.DataFrame(data)

# Save to CSV for UK + US
df.to_csv("sports_boots_sales_profit_demographics_UK_US.csv", index=False)

print("Template CSV created: sports_boots_sales_profit_demographics_UK_US.csv")
# Out:
# Template CSV created: sports_boots_sales_profit_demographics_UK_US.csv
