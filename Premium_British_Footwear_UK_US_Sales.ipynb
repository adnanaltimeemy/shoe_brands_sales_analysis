# %%
import pandas as pd

# Columns
columns = [
    "Brand", "Region", "Year", "Sales_GBP", "Cost_of_Goods_Sold_GBP",
    "Gross_Profit_GBP", "Gross_Margin_pct", "Operating_Expenses_GBP",
    "Operating_Profit_GBP", "Operating_Margin_pct", "Units_Sold",
    "Avg_Price_per_Unit_GBP", "Customer_Age_Median", "Customer_Age_Mean",
    "Customer_Gender_F_pct", "Customer_Gender_M_pct", "Customer_Gender_Other_pct",
    "Top_5_Cities", "Notes", "Data_Source"
]

example_row = {
    "Brand": "Loake",
    "Region": "UK",
    "Year": 2024,
    "Sales_GBP": None,
    "Cost_of_Goods_Sold_GBP": None,
    "Gross_Profit_GBP": None,
    "Gross_Margin_pct": None,
    "Operating_Expenses_GBP": None,
    "Operating_Profit_GBP": None,
    "Operating_Margin_pct": None,
    "Units_Sold": None,
    "Avg_Price_per_Unit_GBP": None,
    "Customer_Age_Median": None,
    "Customer_Age_Mean": None,
    "Customer_Gender_F_pct": None,
    "Customer_Gender_M_pct": None,
    "Customer_Gender_Other_pct": None,
    "Top_5_Cities": None,
    "Notes": "Placeholder row; replace with verified figures from filings, surveys, etc.",
    "Data_Source": "e.g., Companies House filing, press release, internal ERP"
}

# Create DataFrame directly
df = pd.DataFrame([example_row], columns=columns)

output_path = "brand_sales_profit_demographics_template.csv"
df.to_csv(output_path, index=False)

print(f"Template CSV created at: {output_path}")
# Out:
# Template CSV created at: brand_sales_profit_demographics_template.csv

# %%
df = pd.DataFrame(columns=columns)

new_row_df = pd.DataFrame([example_row])
df = pd.concat([df, new_row_df], ignore_index=True)
