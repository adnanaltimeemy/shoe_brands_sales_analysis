# %%
import pandas as pd

# sample data as list of dicts — replace values with actual data
data = [
    {
        "Brand": "Umbro", "Region": "UK", "Year": "2025+", "TotalUnitsSold": 42000,
        "TotalRevenueUSD": 9500000, "ProfitMarginPct": 12.5, "AvgPriceUSD": 118,
        "GenderSplit": "All", "Age18-25Pct": 25, "Age26-40Pct": 40, "Age41+Pct": 20,
        "AgeUnder18Pct": 15, "OnlineSalesPct": 42, "RetailSalesPct": 58,
        "Notes": "Heritage brand; global reach. Sold in 100+ countries."
    },
    {
        "Brand": "Umbro", "Region": "US", "Year": "2025+", "TotalUnitsSold": 36000,
        "TotalRevenueUSD": 8300000, "ProfitMarginPct": 11.0, "AvgPriceUSD": 115,
        "GenderSplit": "All", "Age18-25Pct": 30, "Age26-40Pct": 35, "Age41+Pct": 15,
        "AgeUnder18Pct": 20, "OnlineSalesPct": 47, "RetailSalesPct": 53,
        "Notes": "Growing niche presence vs majors."
    },
    # ... add other rows for Lotto, IDA Sports, Lanzera, and other years ...
]

df = pd.DataFrame(data)

# save to CSV
df.to_csv("boots_sales_demographics_uk_us.csv", index=False)

# optionally preview
print(df.head())
# Out:
#    Brand Region   Year  TotalUnitsSold  TotalRevenueUSD  ProfitMarginPct  \
# 0  Umbro     UK  2025+           42000          9500000             12.5
# 1  Umbro     US  2025+           36000          8300000             11.0
#
#    AvgPriceUSD GenderSplit  Age18-25Pct  Age26-40Pct  Age41+Pct  \
# 0          118         All           25           40         20
# 1          115         All           30           35         15
#
#    AgeUnder18Pct  OnlineSalesPct  RetailSalesPct  \
# 0             15              42              58
# 1             20              47              53
#
#                                                Notes
# 0  Heritage brand; global reach. Sold in 100+ cou...
# 1                  Growing niche presence vs majors.
