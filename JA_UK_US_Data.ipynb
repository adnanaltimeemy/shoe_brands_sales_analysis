# %%
import pandas as pd

sales_df = pd.read_csv("sales_data.csv")
print(sales_df.columns.tolist())
# Out:
# ['Quarter', 'Revenue_USD_m', 'SameStoreSales_Growth_pct']

# %%
sales_df = sales_df.rename(columns={
    "Country Name": "country",
    "Year": "year",
    "Quarter": "quarter"
})

# %%
print(sales_df.columns.tolist())
# Out:
# ['quarter', 'Revenue_USD_m', 'SameStoreSales_Growth_pct']
